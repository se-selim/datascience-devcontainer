# %% [markdown]
# # Lesson 06 in-class demo: functions
#
# ## 1. Functions intro
#
# ### 1.1. Defining functions

# %%
def greeting():
    print('Hello world!')

# %% [markdown]
# ## 1.2. Calling functions

# %%
greeting()
# Out:
# Hello world!

# %% [markdown]
# ## 2. Function arguments
#
# ### 1.1. Single positional argument

# %%
def greet_person(name):
    print(f'Hello {name}')

# %%
greet_person('Alice')
# Out:
# Hello Alice

# %%
greet_person('Bob')
# Out:
# Hello Bob

# %% [markdown]
# ### 1.2. Multiple positional arguments

# %%
def introduce(name, age):
    print(f'My name is {name} and I am {age} years old')

# %%
introduce('Laura', 37)
# Out:
# My name is Laura and I am 37 years old

# %% [markdown]
# ### 1.3. Keyword arguments
#
# - **Positional args** defined by order
# - **Keyword args** defined by name

# %%
introduce(age=30, name='Carol')
# Out:
# My name is Carol and I am 30 years old

# %%
introduce(name='Carol', age=30)
# Out:
# My name is Carol and I am 30 years old

# %% [markdown]
# ## 2.3. Arbitrary arguments

# %%
def add_numbers(*args):
    
    total = 0
    
    for num in args:
        total += num
    
    return total

# %%
result = add_numbers(1,2,3,4,5,6)

# %%
print(result)
# Out:
# 21

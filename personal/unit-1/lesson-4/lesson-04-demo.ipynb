# %% [markdown]
# # Lesson 04 in-class demo
#
# ## 1. Data types
#
# ### 1.1. Strings

# %%
my_string = 'Hello world!'
print(my_string)
# Out:
# Hello world!

# %%
type(my_string)
# Out:
# str

# %%
len(my_string)
# Out:
# 12

# %%
lower_string = my_string.lower()

# %%
print(lower_string)
# Out:
# hello world!

# %% [markdown]
# ### 1.2. Numbers

# %%
my_int = 32
print(my_int)
# Out:
# 32

# %%
type(my_int)
# Out:
# int

# %%
my_float = 32.0

# %%
print(my_float)
# Out:
# 32.0

# %%
type(my_float)
# Out:
# float

# %%
my_float
# Out:
# 32.0

# %%
int(my_float)
# Out:
# 32

# %%
type(int(my_float))
# Out:
# int

# %%
print(my_float)
# Out:
# 32.0

# %%
my_float = 5

# %%
print(my_float)
# Out:
# 5

# %% [markdown]
# ### 1.3. Lists

# %%
my_list = ['zero', 'one', 'two', 'three']
type(my_list)
# Out:
# list

# %%
len(my_list)
# Out:
# 4

# %%
print(my_list)
# Out:
# ['zero', 'one', 'two', 'three']

# %%
my_list.append('four')

# %%
print(my_list)
# Out:
# ['zero', 'one', 'two', 'three', 'four']

# %% [markdown]
# ### 1.4. Dictionaries

# %%
my_dict = {
    'name': 'George',
    'State': 'NY',
    'status': 'Caffinated',
    'Age': 999,
    'Intrests': ['AI', 'ML', 'data science']
}

# %%
type(my_dict)
# Out:
# dict

# %%
print(my_dict)
# Out:
# {'name': 'George', 'State': 'NY', 'status': 'Caffinated', 'Age': 999, 'Intrests': ['AI', 'ML', 'data science']}

# %%
my_dict['name']
# Out:
# 'George'

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'State', 'status', 'Age', 'Intrests'])

# %%
my_dict.values()
# Out:
# dict_values(['George', 'NY', 'Caffinated', 999, ['AI', 'ML', 'data science']])

# %% [markdown]
# ## 2. Working with files
#
# ### 3.1. Reading from a file
#
# **Note:** this example needs a file called `test_file.txt` in the same directory as the notebook to work.

# %%
file = open('data/test_file.txt','r')
type(file)
# Out:
# _io.TextIOWrapper

# %%
contents = file.read()
print(contents)
# Out:
# This is the data!This is more new dataThis is more new dataThis is more new data

# %%
file.close()

# %% [markdown]
# ### 3.2. Context manager

# %%
with open('data/test_file.txt', 'r') as file:
    contents = file.read()
    print(contents)
# Out:
# This is the data!This is more new dataThis is more new dataThis is more new data

# %% [markdown]
# ### 3.3. Writing to a file

# %%
file = open('test_output.txt', 'w')
new_data = 'This is the new data'
file.write(new_data)
file.close()

# %%
file = open('test_output.txt', 'w')
more_data = 'This is more new data'
file.write(more_data)
file.close()

# %%
with open('test_file.txt', 'a') as file:
    more_data = 'This is more new data'
    file.write(more_data)

print(contents)
# Out:
# This is the data!This is more new dataThis is more new dataThis is more new data

# %% [markdown]
# ## 4. Error handling

# %%
file = open('data/bad_file.txt', 'r')
contents = file.read()
print(contents)
file.close()
# Out:
# Now it exists!

# %%
try:

    file = open('data/bad_file.txt', 'r')
    contents = file.read()
    print(contents)

except:

    print('File not found')

finally:

    print('This is the finally clause - it closes the file handle')
    file.close()

print('Do other things')
# Out:
# Now it exists!
# This is the finally clause - it closes the file handle
# Do other things
